# %% [markdown]
# <a href="https://colab.research.google.com/github/Vin25a/01-array/blob/main/PROJECT_TUGAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nilai = []

# Input 10 nilai mahasiswa
for i in range(10):
    n = int(input(f"Masukkan nilai mahasiswa ke-{i+1}: "))
    nilai.append(n)

# Analisis data
nilai_tertinggi = max(nilai)
nilai_terendah = min(nilai)
rata_rata = sum(nilai) / len(nilai)

# Hitung kelulusan
lulus = sum(1 for n in nilai if n >= 60)
tidak_lulus = len(nilai) - lulus

print("\n=== HASIL ===")
print("Nilai:", nilai)
print("Nilai tertinggi:", nilai_tertinggi)
print("Nilai terendah:", nilai_terendah)
print("Rata-rata:", rata_rata)
print("Jumlah lulus:", lulus)
print("Jumlah tidak lulus:", tidak_lulus)
# Out:
# Masukkan nilai mahasiswa ke-1: 70
# Masukkan nilai mahasiswa ke-2: 75
# Masukkan nilai mahasiswa ke-3: 80
# Masukkan nilai mahasiswa ke-4: 85
# Masukkan nilai mahasiswa ke-5: 90
# Masukkan nilai mahasiswa ke-6: 95
# Masukkan nilai mahasiswa ke-7: 90
# Masukkan nilai mahasiswa ke-8: 80
# Masukkan nilai mahasiswa ke-9: 70
# Masukkan nilai mahasiswa ke-10: 60
#
# === HASIL ===
# Nilai: [70, 75, 80, 85, 90, 95, 90, 80, 70, 60]
# Nilai tertinggi: 95
# Nilai terendah: 60
# Rata-rata: 79.5
# Jumlah lulus: 10
# Jumlah tidak lulus: 0

# %%
import matplotlib.pyplot as plt

# grafik nilai tertinggi dan terendah
plt.bar(["Tertinggi", "Terendah"], [nilai_tertinggi, nilai_terendah])
plt.title("Grafik Nilai Mahasiswa")
plt.show()

# %%
plt.pie(
    [lulus, tidak_lulus],
    labels=["Lulus", "Tidak Lulus"],
    autopct="%1.1f%%"
)

plt.title("Persentase Kelulusan")
plt.show()
